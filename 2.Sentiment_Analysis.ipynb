# %% [markdown]
# ## 2. Sentiment Analysis
# Use Vader sentiment analyzer, it was trained using online reviews.

# %%
import pandas as pd
df = pd.read_csv('../dataset/Lyrics_en_clean.csv')
df['sentiment'] = '0'

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

for row in df.itertuples(index=True, name='Pandas'):
    lyric = getattr(row, "Lyrics")
    index = getattr(row, "Index")
    try:
        scores = analyser.polarity_scores(lyric)
        df.at[index, 'sentiment'] = scores['compound']
    except:
        pass
    
df = df.drop(columns="Lyrics")
df.to_csv('../dataset/song_sentiment.csv', index=False)

# %%
df
# Out:
#                          Band                                     Song  \
# 0                Elijah Blake                                 Everyday
# 1                Elijah Blake                         Live Till We Die
# 2                Elijah Blake                            The Otherside
# 3                Elijah Blake                                    Pinot
# 4                Elijah Blake                       Shadows & Diamonds
# 5                Elijah Blake                                      Uno
# 6               Elijah Harris                        Girlfriend (Main)
# 7                 Elijah Levi                        Bye Bye Blackbird
# 8                 Elijah Levi                      Lullaby of Birdland
# 9                 Elijah Levi                          St. Louis Blues
# 10                Elijah Levi         You'd Be So Nice to Come Home To
# 11               Elijah Wyman                              Silhouettes
# 12                 Elin Lanto                   As Long as I Can Dream
# 13           Elin Sigvardsson                           Papercup Words
# 14      Elio e le Storie Tese                              John Holmes
# 15              Eliot Zigmund                            I Wish I Knew
# 16                       Elis                                 Betrayal
# 17                       Elis                                    Child
# 18                       Elis                               Come to Me
# 19                       Elis                           Do You Believe
# 20                       Elis                             My Only Love
# 21                       Elis                                    Anger
# 22                       Elis                              Black Angel
# 23                       Elis                         Devil Inside You
# 24                       Elis                          Heart in Chains
# 25                       Elis                                Lost Soul
# 26                       Elis                             Perfect Love
# 27                       Elis                                  Rebirth
# 28                       Elis                                 Brothers
# 29                       Elis                              The Burning
# ...                       ...                                      ...
# 404698           Demon Hunter                                    Death
# 404699           Demon Hunter                                 Gasoline
# 404700           Demon Hunter                 The Heart of a Graveyard
# 404701           Demon Hunter                       Hell Don't Need Me
# 404702           Demon Hunter                          I Will Fail You
# 404703           Demon Hunter                       The Last One Alive
# 404704           Demon Hunter                            One Last Song
# 404705           Demon Hunter                             What I'm Not
# 404706           Demon Hunter  Hell Don't Need Me [Acoustic] [Version]
# 404707           Demon Hunter     I Will Fail You [Acoustic] [Version]
# 404708           Demon Hunter                          Cold Winter Sun
# 404709           Demon Hunter                                  The End
# 404710           Demon Hunter                          Slight the Odds
# 404711       Demons & Wizards                        Blood on My Hands
# 404712       Demons & Wizards                     Fiddler on the Green
# 404713       Demons & Wizards                             Gallows Pole
# 404714       Demons & Wizards                            Heaven Denies
# 404715       Demons & Wizards                          My Last Sunrise
# 404716       Demons & Wizards                            Path of Glory
# 404717       Demons & Wizards                       Poor Man's Crusade
# 404718       Demons & Wizards                       Tear Down the Wall
# 404719       Demons & Wizards                             The Whistler
# 404720       Demons & Wizards                           White Room [*]
# 404721       Demons & Wizards                          Winter of Souls
# 404722       Demons & Wizards                         Lunar Lament [*]
# 404723       Demons & Wizards                   Spatial Architects [*]
# 404724       Demons & Wizards                      Beneath These Waves
# 404725       Demons & Wizards                             Crimson King
# 404726       Demons & Wizards                                   Dorian
# 404727       Demons & Wizards                          Down Where I Am
#
#        sentiment
# 0        -0.9864
# 1        -0.9983
# 2        -0.9915
# 3        -0.9775
# 4         0.9964
# 5         0.9911
# 6        -0.9637
# 7         0.9826
# 8         0.8176
# 9         0.9705
# 10        0.9868
# 11        0.9646
# 12        0.9787
# 13       -0.9624
# 14        0.9925
# 15        0.4249
# 16       -0.9645
# 17       -0.8832
# 18        0.9854
# 19        0.9817
# 20        0.9698
# 21       -0.9972
# 22       -0.9588
# 23        -0.984
# 24       -0.9934
# 25       -0.9538
# 26        0.9353
# 27        0.5267
# 28        0.9876
# 29       -0.8747
# ...          ...
# 404698   -0.9925
# 404699   -0.9799
# 404700    0.7506
# 404701   -0.9713
# 404702   -0.9944
# 404703    0.9874
# 404704   -0.9936
# 404705   -0.7174
# 404706   -0.9713
# 404707   -0.9926
# 404708   -0.9828
# 404709    0.8871
# 404710     -0.99
# 404711   -0.9774
# 404712    0.7385
# 404713   -0.9916
# 404714   -0.9726
# 404715   -0.9989
# 404716    0.9728
# 404717   -0.9901
# 404718   -0.9413
# 404719    0.9854
# 404720   -0.6705
# 404721    -0.999
# 404722    0.7339
# 404723   -0.9888
# 404724    0.7978
# 404725   -0.7835
# 404726    0.7047
# 404727   -0.9884
#
# [404728 rows x 3 columns]
